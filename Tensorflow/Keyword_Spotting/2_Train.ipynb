# %% [markdown]
# # Training

# %%
import json
import numpy as np
import tensorflow.keras as keras # Keras is a high-level API to build and train deep learning models.
from sklearn.model_selection import train_test_split

DATA_PATH = "speech_commands_v0.01_data.json"
SAVED_MODEL_PATH = "model.h5"

LEARNING_RATE = 0.0001
EPOCHS = 40
BATH_SIZE = 32

NUM_KEYWORDS = 14

# %%
def load_dataset(data_path):
    
    with open(data_path, "r") as fp:
        data = json.load(fp)
    
    # extract features (inputs) and targets an np.arrays.
    X = np.array(data["MFCCs"])
    y = np.array(data["labels"])
    
    return X, y
    
    
def get_data_splits(data_path, test_size = 0.1, test_validation = 0.1):
    
    # load datasets
    X, y = load_dataset(data_path)
    # Create train/validation/test splits
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=test_validation)
    
    
    # convert inputs from 2d to 3d arrays
    # (# segments, 13) -> (# segments, 13, 1)
    X_train = X_train[..., np.newaxis] #...gives all the data in the array + np.newaxis adds a new dimension
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]
    
    return X_train, X_validation, X_test, y_train, y_validation, y_test

# %%
# Build the CNN model
# Detailed explanation of particular layers "Audio DeepLearning" notebook"

def build_model(input_shape, learning_rate, error="sparse_categorical_crossentropy"):

    # Build network topology
    model = keras.Sequential()  # Sequential model is a linear stack of layers, one leads to nother
    
    # conv. layer 1
    # args: number of folters (64), kernel size (3,3) ( size of the filter), activation function (relu), 
    # args: input shape (shabe of the input data), regularizer (to avoid overfitting).
    model.add(keras.layers.Conv2D(64, (3, 3), activation="relu",
                                  input_shape=input_shape, 
                                  kernel_regularizer=keras.regularizers.l2(0.001)))
    # batch notmalization layer - speedup training
    model.add(keras.layers.BatchNormalization())
    # maxpooling - reduce the size of the feature maps (downsamples output of conv. layer)
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2,2), padding="same"))
    
    # conv. layer 2
    model.add(keras.layers.Conv2D(32, (3, 3), activation="relu", kernel_regularizer=keras.regularizers.l2(0.001)))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.MaxPooling2D((3, 3), strides=(2,2), padding="same"))
    
    # conv. layer 3
    model.add(keras.layers.Conv2D(32, (2, 2), activation="relu", kernel_regularizer=keras.regularizers.l2(0.001)))
    model.add(keras.layers.BatchNormalization())
    model.add(keras.layers.MaxPooling2D((2, 2), strides=(2,2), padding="same"))
    
    # flatten output and feed it into dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation="relu"))
    model.add(keras.layers.Dropout(0.3)) # dropout layer to avoid overfitting, 
    # shoots down 30% of the neurons in the dense layer during training.
    
    # softmax classifier
    model.add(keras.layers.Dense(NUM_KEYWORDS, activation="softmax")) # outputs eg.: [0.1, 0.7, 0.2] -> [0, 1, 0]
    
    
    # Compile the model
    optimiser = keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimiser,
                  loss=error, metrics=["accuracy"])
    
    # Print model overview
    model.summary()
    
    return model

# %%
def main():
    
    # Load train/validation/test data splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = get_data_splits(DATA_PATH)

    # Build the CNN model
    # Extracting input shape from X_train, index 1, 2, 3 to 3D shape o the input
    input_shape = (X_train.shape[1], X_train.shape[2], X_train.shape[3]) # 1D - number of segments, 2D - number of coefficients , 3D - number of channels (DEPTH) of an image (1 - MFCC - grayscale)
    model = build_model(input_shape, LEARNING_RATE)
    
    # Train the model
    model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=EPOCHS)
    
    # Evaluate the model
    test_error, test_accuracy = model.evaluate(X_test, y_test)
    print(f"Test error: {test_error}, test accuracy: {test_accuracy}")
    
    # Save the model
    model.save(SAVED_MODEL_PATH)
    
    # Save test file paths to json
    with open("test_files.json", "w") as fp:
        json.dump({"path": X_test.tolist()}, fp)
    
    
if __name__ == "__main__":
    main()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 42, 11, 64)        640
#
#  batch_normalization (Batch  (None, 42, 11, 64)        256
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 21, 6, 64)         0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 19, 4, 32)         18464
#
#  batch_normalization_1 (Bat  (None, 19, 4, 32)         128
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 10, 2, 32)         0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 9, 1, 32)          4128
#
#  batch_normalization_2 (Bat  (None, 9, 1, 32)          128
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 5, 1, 32)          0
#  g2D)
#
#  flatten (Flatten)           (None, 160)               0
#
#  dense (Dense)               (None, 64)                10304
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 14)                910
#
# =================================================================
# Total params: 34958 (136.55 KB)
# Trainable params: 34702 (135.55 KB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________
# Epoch 1/40
# 672/672 [==============================] - 13s 17ms/step - loss: 2.5777 - accuracy: 0.2160 - val_loss: 1.9300 - val_accuracy: 0.4274
# Epoch 2/40
# 672/672 [==============================] - 11s 17ms/step - loss: 1.8465 - accuracy: 0.4238 - val_loss: 1.4101 - val_accuracy: 0.5986
# Epoch 3/40
# 672/672 [==============================] - 11s 17ms/step - loss: 1.4053 - accuracy: 0.5687 - val_loss: 1.0377 - val_accuracy: 0.7116
# Epoch 4/40
# 672/672 [==============================] - 12s 17ms/step - loss: 1.1028 - accuracy: 0.6632 - val_loss: 0.8324 - val_accuracy: 0.7777
# Epoch 5/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.9104 - accuracy: 0.7250 - val_loss: 0.6794 - val_accuracy: 0.8121
# Epoch 6/40
# 672/672 [==============================] - 12s 17ms/step - loss: 0.7918 - accuracy: 0.7629 - val_loss: 0.5932 - val_accuracy: 0.8359
# Epoch 7/40
# 672/672 [==============================] - 12s 17ms/step - loss: 0.7115 - accuracy: 0.7886 - val_loss: 0.5497 - val_accuracy: 0.8468
# Epoch 8/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.6472 - accuracy: 0.8105 - val_loss: 0.5116 - val_accuracy: 0.8527
# Epoch 9/40
# 672/672 [==============================] - 11s 16ms/step - loss: 0.6076 - accuracy: 0.8271 - val_loss: 0.4858 - val_accuracy: 0.8644
# Epoch 10/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.5633 - accuracy: 0.8404 - val_loss: 0.4562 - val_accuracy: 0.8719
# Epoch 11/40
# 672/672 [==============================] - 12s 17ms/step - loss: 0.5344 - accuracy: 0.8493 - val_loss: 0.4263 - val_accuracy: 0.8861
# Epoch 12/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.5043 - accuracy: 0.8586 - val_loss: 0.4275 - val_accuracy: 0.8832
# Epoch 13/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.4849 - accuracy: 0.8646 - val_loss: 0.4126 - val_accuracy: 0.8899
# Epoch 14/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.4629 - accuracy: 0.8725 - val_loss: 0.3859 - val_accuracy: 0.8983
# Epoch 15/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.4478 - accuracy: 0.8769 - val_loss: 0.3933 - val_accuracy: 0.8945
# Epoch 16/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.4301 - accuracy: 0.8817 - val_loss: 0.4073 - val_accuracy: 0.8920
# Epoch 17/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.4126 - accuracy: 0.8908 - val_loss: 0.3687 - val_accuracy: 0.8966
# Epoch 18/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.3973 - accuracy: 0.8931 - val_loss: 0.3820 - val_accuracy: 0.8928
# Epoch 19/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.3902 - accuracy: 0.8975 - val_loss: 0.3555 - val_accuracy: 0.9079
# Epoch 20/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.3808 - accuracy: 0.8996 - val_loss: 0.3482 - val_accuracy: 0.9096
# Epoch 21/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.3701 - accuracy: 0.9015 - val_loss: 0.3438 - val_accuracy: 0.9142
# Epoch 22/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.3587 - accuracy: 0.9067 - val_loss: 0.3549 - val_accuracy: 0.9054
# Epoch 23/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.3452 - accuracy: 0.9101 - val_loss: 0.3387 - val_accuracy: 0.9113
# Epoch 24/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.3411 - accuracy: 0.9133 - val_loss: 0.3483 - val_accuracy: 0.9050
# Epoch 25/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.3293 - accuracy: 0.9161 - val_loss: 0.3267 - val_accuracy: 0.9150
# Epoch 26/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.3239 - accuracy: 0.9159 - val_loss: 0.3320 - val_accuracy: 0.9138
# Epoch 27/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.3114 - accuracy: 0.9188 - val_loss: 0.3248 - val_accuracy: 0.9142
# Epoch 28/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.3073 - accuracy: 0.9226 - val_loss: 0.3152 - val_accuracy: 0.9205
# Epoch 29/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.3067 - accuracy: 0.9211 - val_loss: 0.3276 - val_accuracy: 0.9146
# Epoch 30/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.2896 - accuracy: 0.9268 - val_loss: 0.3105 - val_accuracy: 0.9251
# Epoch 31/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.2936 - accuracy: 0.9247 - val_loss: 0.3125 - val_accuracy: 0.9209
# Epoch 32/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.2873 - accuracy: 0.9262 - val_loss: 0.3114 - val_accuracy: 0.9175
# Epoch 33/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.2795 - accuracy: 0.9297 - val_loss: 0.3626 - val_accuracy: 0.9041
# Epoch 34/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.2775 - accuracy: 0.9310 - val_loss: 0.3119 - val_accuracy: 0.9201
# Epoch 35/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.2679 - accuracy: 0.9336 - val_loss: 0.3083 - val_accuracy: 0.9213
# Epoch 36/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.2654 - accuracy: 0.9345 - val_loss: 0.3073 - val_accuracy: 0.9213
# Epoch 37/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.2626 - accuracy: 0.9339 - val_loss: 0.3266 - val_accuracy: 0.9121
# Epoch 38/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.2539 - accuracy: 0.9363 - val_loss: 0.2984 - val_accuracy: 0.9255
# Epoch 39/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.2512 - accuracy: 0.9378 - val_loss: 0.3237 - val_accuracy: 0.9146
# Epoch 40/40
# 672/672 [==============================] - 11s 17ms/step - loss: 0.2489 - accuracy: 0.9388 - val_loss: 0.2955 - val_accuracy: 0.9259
# 83/83 [==============================] - 0s 5ms/step - loss: 0.2921 - accuracy: 0.9277
# Test error: 0.2921268045902252, test accuracy: 0.927656352519989
# d:\Code\ProjectsPython\ML_TrainingGround\CustomAudio\.venv\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
